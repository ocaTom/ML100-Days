# %% [markdown]
# # 作業1：請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# ## 1. 你選的這組資料為何重要
# ### 我選擇的是 Dataset 中的 QuickDraw Sketches
# ### 在圖像辨識中，不容易取得有正確答案的資料，有正確答案的資料對進行監督式學習很有幫助
#
# ## 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# ### 提供者是 Google，QuickDraw 是一個網頁的遊戲，方式是由系統指定題目，玩家作畫，而玩家作畫的過程中 google 的圖片辨識系統也會一直進行猜測玩家所畫的是什麼
#
# ## 3. 蒐集而來的資料型態為何
# ### ndjson (Newline Delimited JSON)，每一行皆為一筆 JSON 格式的資料，以 '\n' 分隔資料
#
# ## 4. 這組資料想解決的問題如何評估
# ### 用監督式演算法進行預測就可以用準確度評估演算法優劣

# %% [markdown]
# # 作業二：想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
#
# ## 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# ### 提升業績的標準可以是月營業額提升、單月載客數提升
# ### 哪些地區的業績較差？ 一個禮拜哪一天業績較差？ 什麼天氣的業績會比較好？
#
# ## 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# ### 叫車、上下車的地點及叫車的時間點以及當日的天氣狀況
# ### 地點及時間應該藉由叫車系統(App或電話叫車)匯入公司資料庫中
# ### 天氣資料可透過中央氣象局開放資料平臺之資料擷取API獲得
#
# ## 3. 蒐集而來的資料型態為何
# ### 資料庫匯出的資料可以是 JSON 或 CSV
# ### 天氣資料為 JSON
#
# ## 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# ### 利用統計分析出哪些地點、時間的業績較差，進行人力上的調派
# ### 利用決策樹分析天氣與叫車數的關係

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    err_sum = 0
    for i in range(len(y)):
        err_sum += ((y[i] - y_hat[i]) ** 2)
    return err_sum/len(y)

def mean_absolute_error(y, y_hat):
    err_sum = 0
    for i in range(len(y)):
        err_sum += abs(y[i] - y_hat[i])
    return err_sum/len(y)

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 244.771
# The Mean absolute error is 12.991
